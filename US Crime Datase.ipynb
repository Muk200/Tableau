# %% [markdown]
# # **Which state has max numbers of victims/crimes**
# ---
#
# using victim count, we can determine both
#
#     - Longitude = cols & lattitude = rows
#     - states = details
#     - victim count = color
#     - filters = years
# where we can check in range of say
# 2000 - 2014 or in a particular yr
#
# ![](https://drive.google.com/uc?export=view&id=14WYnIH7S13-3ziLU33JZz4BGjlUMC2zB)
#
# ---
#
# `weapons`
#
#   - use details = city
#   - weapons = colors
#
# ![](https://drive.google.com/uc?export=view&id=1Tg-6wrPp4ytOkOhcVSZNmzQNcZZBKtZw)

# %% [markdown]
# # **Which city has most amt of perpetrators**
# ---
# similar to victim but use perpetrator instead
#
# check if victim & perpetrator cnt are directly corelated or not
#
#     - state = cols
#     - perpetrator/victim cnt = rows
#
# *use dual axis for better observations*
#
# *Line for victim cnt*
#
# > **both have direct correlation**
#
# ![](https://drive.google.com/uc?export=view&id=1Y7NO8qz9LEm7q2c6yNaV3hOik-a6dbhv)

# %% [markdown]
# **1. Generated fields**
#
# can be created & visible in data pane with addition to already present fields in data itself.
#
# - measure names
# - measure values
# - no of records
# - latitude & longitude
#
# **2. use cases of these generated fields**
#
# `measure names = cols`
# `measure vals = rows`
#
# *can also create alias for measure name*
#
# `no of record = rows`
#
# ![](https://drive.google.com/uc?export=view&id=1SfC0My-yECpdFNpdJWlEPhCaP0nQDFYL)

# %% [markdown]
# # **FEATURES**
# ---
#
# 1. amazing data visualization
# 2. data src integration
# 3. quality customer support
# 4. easy implementation
# 5. mobile support
# 6. online community

# %% [markdown]
# # **CHARTS & GRAPHS**
# ---
#
# **`BAR CHART`**
#
# compare data across diff categories
#
# - state = col & victim count = rows
#
#  ![](https://drive.google.com/uc?export=view&id=1xmPibSxwBs2xEb6Gd93BOzf1BPitdtdP)
#
#  ---
#
# **`LINE CHART`**
#
#  compare data across the diff periods
#
#  - year = cols & incidents = rows
#
# ![](https://drive.google.com/uc?export=view&id=1moicgfePBG3PdiMROwTQgCtu6yoU02nF)
#
# ---
#
# **`PARETO CHART`**
#
# consists of both bar + line
#
# *to identify the members present in a particular field*
#
# - city = cols , perpetrator age = rows
# - rows vals taken twice cuz we want x & x axis to be separate.
#
# 1. Sort the COLS in desc order by fields
# 2. do the dual axis in rows, need to separate the x axis of both the measures used aka rows
# 3. take bar for one row measure and line for other
# 4. one of the vals of row , add table cal
# 5. for cal type - running total, compute using - table across
# 6. add a secondary cal, type - percent of total.
#
# ![](https://drive.google.com/uc?export=view&id=1Sos5yyoWsPFBM-Ri-PXaHOULWcS08yNG)
#
# ---
#
# **`BULLET CHART`**
#
# used to show performance of measures
#
# *two measure can be compared here*
#
# > Analysis -> created calculated fields -> write a expression
#
# *Use victim count & estimated victim count*
#
# ![](https://drive.google.com/uc?export=view&id=1te5jpBIBu23YdEJD1dToO4P5N8WPnIaF)
#
# ---
#
# **`TEXT TABLES`**
#
# show the exact val of measure across the diff dimension aka field
#
# - months = rows & incident = text
#
# ![](https://drive.google.com/uc?export=view&id=16OYbHjNkivEMzOFP_2L9MWi4drdDslCB)
#
# ---
#
# **`HEAT MAP`**
#
# visualize data in form of size & color on diff measures.
#
# shows the density of values(measure)
#
# - cols = weapons & years
# - color = vitim count
# - label = victim age
#
# ![](https://drive.google.com/uc?export=view&id=1q5enl4YRy24PFQ0dz3BAz7XE0NGYMdkt)
#
# ---
#
# **`WATERFALL CHART`**
#
# for the cumulative effect of a val(measure) over field(dimenstion).
#
# shows growth or decline by each member of the field
#
# 1. take bar chart, in rows (vic cnt)
# 2. create a -ve of that in cal field
# 3. add this in size option
# 4. in the row , do a running total for quick table cal
# 5. turn it into a gantt chart
#
# ![](https://drive.google.com/uc?export=view&id=11FFA17sLFmhBUOw6IkSS0i3NDktpidlF)
#
# ---
#
# **`GANTT CHART`**
#
# used to identify the time taken for diff categories. aka data & category
#
# ![](https://drive.google.com/uc?export=view&id=1TKryiUaSt-bejsM73oh9dR5nborEqCy_)
#
# ---
#
# **`PIE CHART`**
#
# contribution of val over different members of field
#
# ![](https://drive.google.com/uc?export=view&id=1DKetCJUGgcRP9PnpedvjoDAYg5-IxEMy)
#
# ---
#
# **`SCATTER PLOT`**
#
# shows the trend or relation b/w different vals
#
# - row = perpetrator cnt
# - col = victim count
# - color = state
#
# ![](https://drive.google.com/uc?export=view&id=1pdCUgmh3UV2Rz6K_DshySeD2a8FsELK4)
#
# ---
#
# **`AREA CHART`**
#
# represent any val over different period of time
# similar to line graph but area under line is filled with color to show density.
#
# - col = year , row = victim(age)
# - color = states
#
# ![](https://drive.google.com/uc?export=view&id=1Q9HUgxPzrXOldMtHpVsL0jka3y57SZ_R)
#
# ---
#
# **`DUAL AXIS`**
#
# to visualize 2 diff vals in 2 diff chart types
#
# - col = year
# - row = perpetrator & victim count
#
# ![](https://drive.google.com/uc?export=view&id=15JhJlSrQQNi05OdRGFcvdm_FzctDUDYJ)
#
# ---
#
# **`BUBBLE CHART`**
#
# visualize the val & fields in form of bubbles similar to scatter but more effective visualization
#
# - shape = perpetrator count
# - labels = state
# - color = weapons
#
# ![](https://drive.google.com/uc?export=view&id=1oAlP9u9HsI0_EamI-Zlr_pcFEvUiLLMY)
#
# ---
#
# **`HISTOGRAM`**
#
# show distribution of numerical data & it's frequency.
#
# ![](https://drive.google.com/uc?export=view&id=1hUGiDTybDl1ztF_UxnV3ta23jsQV5oa9)
#
# ---
