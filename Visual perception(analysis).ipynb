# %% [markdown]
# # **VISUAL ANALYSIS**
# ---
# Training insights from a visual interface & represent data as accurate as possible.
#
# `Aquire -> Filter -> Enhance -> Tune -> Deliver`
#
# Learning in two ways
#
#    - Attentive
#    - Pre Attentive
#
# ![](https://drive.google.com/uc?export=view&id=10QXa-JVQHiX_N-FyX5Eaev-ZAmrl7dZO)
#
# *to find ways in which we can give more insights in less attentive way*
#
# *ex - for sales, instead of using pie charts , use bar as they are less attentive*

# %% [markdown]
# # **COMPONENTS OF TABLEAU**
# ---
#
# ![](https://drive.google.com/uc?export=view&id=15xoE47wIlkhIK3oYjOnOkv7iHVr6bRM0)
#
# **`Desktop :`**
# - it's self service
# - can be used by anyone.
# - pics of data into optimized db.
# - Connect directly to data from data warehouse for UpToDate analysis.
# - write queries without writing code .
# - import data from multiple srcs & integrate them.
# - combine multiple views
#
# **`Server : `**
#
# - enterprise based, they have to buy it
# - fast dataBases through live connections
# - use it throughout the organisation
#
# **`Online :`**
#
# - hosted version
# - makes BI faster & easier
# - can be shared to ppl not in a particular grp
#
# **`Reader :`**
#
# - free app
# - only view
# - can filter & drill down but can't edit or perform
#
# **`Public :`**
#
# - can't keep it private, have to publish them

# %% [markdown]
# # **PROS**
# ---
# 1. easy to use
# 2. direct connection & go
# 3. perfect mashups (join diff data)
# 4. best practices in a box(package of all needed)
